# %% [markdown]
# <a href="https://colab.research.google.com/github/DeveloperCorsair/colab/blob/main/Start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tabela = pd.read_excel("/content/drive/MyDrive/henrique1.xlsx")
display(tabela)
# Out:
#     Unnamed: 0                                      Unnamed: 1  Unnamed: 2  \
# 0          NaN  GASTOS PESSOAIS MORANDO EM SÃO JOSÉ DOS CAMPOS         NaN
# 1          NaN                                        Despesas     Janeiro
# 2          NaN                                         Aluguel        2500
# 3          NaN                                          Escola        1400
# 4          NaN                                    Supermercado         640
# 5          NaN                                       Farmácia          150
# 6          NaN                                        Internet          75
# 7          NaN                              Gasto (Trimestral)       14051
# 8          NaN                       Total (Todas as despesas)         NaN
# 9          NaN                                             NaN         NaN
# 10         NaN                                Média Trimestral  936.733333
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python '/content/Exercício 1.py'
# Out:
# python3: can't open file '/content/Exercício 1.py': [Errno 2] No such file or directory

# %%
import plotly.express as px
